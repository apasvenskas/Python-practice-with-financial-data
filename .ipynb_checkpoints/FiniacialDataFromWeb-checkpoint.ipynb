# %% [markdown]
# Loading Financial Data from Web

# %%
import pandas as pd
import yfinance as yf

# %%
start = "2014-10-01"
end = "2021-05-31"

# %%
symbol ="BA"

# %%
yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-10-01  127.370003  127.370003  124.309998  124.669998  108.406677
# 2014-10-02  124.400002  125.550003  123.839996  124.169998  107.971886
# 2014-10-03  124.660004  126.870003  124.660004  126.360001  109.876213
# 2014-10-06  127.089996  127.190002  125.379997  126.260002  109.789261
# 2014-10-07  125.519997  125.519997  123.290001  123.320000  107.232780
# ...                ...         ...         ...         ...         ...
# 2021-05-24  235.139999  238.500000  232.600006  237.440002  237.440002
# 2021-05-25  240.000000  243.779999  239.229996  240.740005  240.740005
# 2021-05-26  241.699997  242.490005  239.869995  241.369995  241.369995
# 2021-05-27  248.110001  252.600006  247.190002  250.699997  250.699997
# 2021-05-28  247.479996  248.979996  245.369995  247.020004  247.020004
#
#               Volume
# Date
# ...

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-10-01  127.370003  127.370003  124.309998  124.669998  108.406677
# 2014-10-02  124.400002  125.550003  123.839996  124.169998  107.971886
# 2014-10-03  124.660004  126.870003  124.660004  126.360001  109.876213
# 2014-10-06  127.089996  127.190002  125.379997  126.260002  109.789261
# 2014-10-07  125.519997  125.519997  123.290001  123.320000  107.232780
# ...                ...         ...         ...         ...         ...
# 2021-05-24  235.139999  238.500000  232.600006  237.440002  237.440002
# 2021-05-25  240.000000  243.779999  239.229996  240.740005  240.740005
# 2021-05-26  241.699997  242.490005  239.869995  241.369995  241.369995
# 2021-05-27  248.110001  252.600006  247.190002  250.699997  250.699997
# 2021-05-28  247.479996  248.979996  245.369995  247.020004  247.020004
#
#               Volume
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1677 entries, 2014-10-01 to 2021-05-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1677 non-null   float64
#  1   High       1677 non-null   float64
#  2   Low        1677 non-null   float64
#  3   Close      1677 non-null   float64
#  4   Adj Close  1677 non-null   float64
#  5   Volume     1677 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 91.7 KB

# %%
symbol = ["BA", "MSFT", "DJI", "EURUSD=X", "GC=F", "BTC=USD"]

# %%
symbol
# Out:
# ['BA', 'MSFT', 'DJI', 'EURUSD=X', 'GC=F', 'BTC=USD']

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%***********************]  6 of 6 completed
#
# 1 Failed download:
# ['BTC=USD']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Price                       Adj Close                                  \
# Ticker                             BA BTC=USD           DJI  EURUSD=X
# Date
# 2014-10-01 00:00:00+00:00  108.406677     NaN  16804.699219  1.262834
# 2014-10-02 00:00:00+00:00  107.971886     NaN  16801.099609  1.262419
# 2014-10-03 00:00:00+00:00  109.876213     NaN  17009.699219  1.267058
# 2014-10-06 00:00:00+00:00  109.789261     NaN  16991.900391  1.251361
# 2014-10-07 00:00:00+00:00  107.232780     NaN  16719.400391  1.264606
# ...                               ...     ...           ...       ...
# 2021-05-24 00:00:00+00:00  237.440002     NaN  34394.000000  1.218324
# 2021-05-25 00:00:00+00:00  240.740005     NaN  34312.500000  1.221464
# 2021-05-26 00:00:00+00:00  241.369995     NaN  34323.101562  1.224909
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1738 entries, 2014-10-01 00:00:00+00:00 to 2021-05-28 00:00:00+00:00
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        1677 non-null   float64
#  1   (Adj Close, BTC=USD)   0 non-null      float64
#  2   (Adj Close, DJI)       1517 non-null   float64
#  3   (Adj Close, EURUSD=X)  1735 non-null   float64
#  4   (Adj Close, GC=F)      1674 non-null   float64
#  5   (Adj Close, MSFT)      1677 non-null   float64
#  6   (Close, BA)            1677 non-null   float64
#  7   (Close, BTC=USD)       0 non-null      float64
#  8   (Close, DJI)           1517 non-null   float64
#  9   (Close, EURUSD=X)      1735 non-null   float64
#  10  (Close, GC=F)          1674 non-null   float64
#  11  (Close, MSFT)          1677 non-null   float64
#  12  (High, BA)             1677 non-null   float64
# ...

# %%
df.to_csv("multi_assets.csv")

# %% [markdown]
# Initial Inspection and Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
print(plt.style.available)  # check available style names
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
pd.read_csv("multi_assets.csv")
# Out:
#                           Price           Adj Close Adj Close.1  \
# 0                        Ticker                  BA     BTC=USD
# 1                          Date                 NaN         NaN
# 2     2014-10-01 00:00:00+00:00  108.40667724609375         NaN
# 3     2014-10-02 00:00:00+00:00  107.97188568115234         NaN
# 4     2014-10-03 00:00:00+00:00  109.87621307373047         NaN
# ...                         ...                 ...         ...
# 1735  2021-05-24 00:00:00+00:00  237.44000244140625         NaN
# 1736  2021-05-25 00:00:00+00:00  240.74000549316406         NaN
# 1737  2021-05-26 00:00:00+00:00   241.3699951171875         NaN
# 1738  2021-05-27 00:00:00+00:00   250.6999969482422         NaN
# 1739  2021-05-28 00:00:00+00:00  247.02000427246094         NaN
#
#           Adj Close.2         Adj Close.3         Adj Close.4  \
# 0                 DJI            EURUSD=X                GC=F
# 1                 NaN                 NaN                 NaN
# ...

# %%
df = pd.read_csv("multi_assets.csv", header = [0, 1], index_col = 0, parse_dates = [0])
df
# Out:
# Price                     Adj Close                                        \
# Ticker                           BA BTC=USD        DJI EURUSD=X      GC=F
# Date
# 2014-10-01 00:00:00+00:00  108.4067     NaN 16804.6992   1.2628 1214.6000
# 2014-10-02 00:00:00+00:00  107.9719     NaN 16801.0996   1.2624 1214.2000
# 2014-10-03 00:00:00+00:00  109.8762     NaN 17009.6992   1.2671 1192.2000
# 2014-10-06 00:00:00+00:00  109.7893     NaN 16991.9004   1.2514 1206.7000
# 2014-10-07 00:00:00+00:00  107.2328     NaN 16719.4004   1.2646 1211.7000
# ...                             ...     ...        ...      ...       ...
# 2021-05-24 00:00:00+00:00  237.4400     NaN 34394.0000   1.2183 1884.6000
# 2021-05-25 00:00:00+00:00  240.7400     NaN 34312.5000   1.2215 1898.1000
# 2021-05-26 00:00:00+00:00  241.3700     NaN 34323.1016   1.2249 1901.3000
# 2021-05-27 00:00:00+00:00  250.7000     NaN 34464.6016   1.2193 1895.7000
# 2021-05-28 00:00:00+00:00  247.0200     NaN 34529.3984   1.2193 1902.5000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1738 entries, 2014-10-01 00:00:00+00:00 to 2021-05-28 00:00:00+00:00
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        1677 non-null   float64
#  1   (Adj Close, BTC=USD)   0 non-null      float64
#  2   (Adj Close, DJI)       1517 non-null   float64
#  3   (Adj Close, EURUSD=X)  1735 non-null   float64
#  4   (Adj Close, GC=F)      1674 non-null   float64
#  5   (Adj Close, MSFT)      1677 non-null   float64
#  6   (Close, BA)            1677 non-null   float64
#  7   (Close, BTC=USD)       0 non-null      float64
#  8   (Close, DJI)           1517 non-null   float64
#  9   (Close, EURUSD=X)      1735 non-null   float64
#  10  (Close, GC=F)          1674 non-null   float64
#  11  (Close, MSFT)          1677 non-null   float64
#  12  (High, BA)             1677 non-null   float64
# ...

# %%
df.Close
# Out:
# Ticker                          BA  BTC=USD        DJI  EURUSD=X      GC=F  \
# Date
# 2014-10-01 00:00:00+00:00 124.6700      NaN 16804.6992    1.2628 1214.6000
# 2014-10-02 00:00:00+00:00 124.1700      NaN 16801.0996    1.2624 1214.2000
# 2014-10-03 00:00:00+00:00 126.3600      NaN 17009.6992    1.2671 1192.2000
# 2014-10-06 00:00:00+00:00 126.2600      NaN 16991.9004    1.2514 1206.7000
# 2014-10-07 00:00:00+00:00 123.3200      NaN 16719.4004    1.2646 1211.7000
# ...                            ...      ...        ...       ...       ...
# 2021-05-24 00:00:00+00:00 237.4400      NaN 34394.0000    1.2183 1884.6000
# 2021-05-25 00:00:00+00:00 240.7400      NaN 34312.5000    1.2215 1898.1000
# 2021-05-26 00:00:00+00:00 241.3700      NaN 34323.1016    1.2249 1901.3000
# 2021-05-27 00:00:00+00:00 250.7000      NaN 34464.6016    1.2193 1895.7000
# 2021-05-28 00:00:00+00:00 247.0200      NaN 34529.3984    1.2193 1902.5000
#
# Ticker                        MSFT
# Date
# ...

# %%
df.Close.BA
# Out:
# Date
# 2014-10-01 00:00:00+00:00   124.6700
# 2014-10-02 00:00:00+00:00   124.1700
# 2014-10-03 00:00:00+00:00   126.3600
# 2014-10-06 00:00:00+00:00   126.2600
# 2014-10-07 00:00:00+00:00   123.3200
#                               ...
# 2021-05-24 00:00:00+00:00   237.4400
# 2021-05-25 00:00:00+00:00   240.7400
# 2021-05-26 00:00:00+00:00   241.3700
# 2021-05-27 00:00:00+00:00   250.7000
# 2021-05-28 00:00:00+00:00   247.0200
# Name: BA, Length: 1738, dtype: float64

# %%
df.loc[:, ("Close", "BA")]
# Out:
# Date
# 2014-10-01 00:00:00+00:00   124.6700
# 2014-10-02 00:00:00+00:00   124.1700
# 2014-10-03 00:00:00+00:00   126.3600
# 2014-10-06 00:00:00+00:00   126.2600
# 2014-10-07 00:00:00+00:00   123.3200
#                               ...
# 2021-05-24 00:00:00+00:00   237.4400
# 2021-05-25 00:00:00+00:00   240.7400
# 2021-05-26 00:00:00+00:00   241.3700
# 2021-05-27 00:00:00+00:00   250.7000
# 2021-05-28 00:00:00+00:00   247.0200
# Name: (Close, BA), Length: 1738, dtype: float64

# %%
df.loc["2015-01-07"]
# Out:
# Price      Ticker
# Adj Close  BA              113.2724
#            BTC=USD              NaN
#            DJI           17584.5000
#            EURUSD=X          1.1875
#            GC=F           1210.6000
#            MSFT             39.7768
# Close      BA              129.5100
#            BTC=USD              NaN
#            DJI           17584.5000
#            EURUSD=X          1.1875
#            GC=F           1210.6000
#            MSFT             46.2300
# High       BA              129.9700
#            BTC=USD              NaN
#            DJI           17584.5000
#            EURUSD=X          1.1900
#            GC=F           1219.2000
#            MSFT             46.4600
# Low        BA              128.7200
#            BTC=USD              NaN
#            DJI           17584.5000
#            EURUSD=X          1.1804
#            GC=F           1210.6000
#            MSFT             45.4900
# Open       BA              128.7400
# ...

# %%
df.loc["2020-06":, ("Close", "BA")]
# Out:
# Date
# 2020-06-01 00:00:00+00:00   151.3900
# 2020-06-02 00:00:00+00:00   153.3100
# 2020-06-03 00:00:00+00:00   173.1600
# 2020-06-04 00:00:00+00:00   184.3000
# 2020-06-05 00:00:00+00:00   205.4300
#                               ...
# 2021-05-24 00:00:00+00:00   237.4400
# 2021-05-25 00:00:00+00:00   240.7400
# 2021-05-26 00:00:00+00:00   241.3700
# 2021-05-27 00:00:00+00:00   250.7000
# 2021-05-28 00:00:00+00:00   247.0200
# Name: (Close, BA), Length: 260, dtype: float64

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = "columns")
df
# Out:
# Price                     Adj Close                                        \
# Ticker                           BA BTC=USD        DJI EURUSD=X      GC=F
# Date
# 2014-10-01 00:00:00+00:00  108.4067     NaN 16804.6992   1.2628 1214.6000
# 2014-10-02 00:00:00+00:00  107.9719     NaN 16801.0996   1.2624 1214.2000
# 2014-10-03 00:00:00+00:00  109.8762     NaN 17009.6992   1.2671 1192.2000
# 2014-10-06 00:00:00+00:00  109.7893     NaN 16991.9004   1.2514 1206.7000
# 2014-10-07 00:00:00+00:00  107.2328     NaN 16719.4004   1.2646 1211.7000
# ...                             ...     ...        ...      ...       ...
# 2021-05-24 00:00:00+00:00  237.4400     NaN 34394.0000   1.2183 1884.6000
# 2021-05-25 00:00:00+00:00  240.7400     NaN 34312.5000   1.2215 1898.1000
# 2021-05-26 00:00:00+00:00  241.3700     NaN 34323.1016   1.2249 1901.3000
# 2021-05-27 00:00:00+00:00  250.7000     NaN 34464.6016   1.2193 1895.7000
# 2021-05-28 00:00:00+00:00  247.0200     NaN 34529.3984   1.2193 1902.5000
#
# ...

# %%
df[('Close', 'EURUSD=X')]
# Out:
# Date
# 2014-10-01 00:00:00+00:00   1.2628
# 2014-10-02 00:00:00+00:00   1.2624
# 2014-10-03 00:00:00+00:00   1.2671
# 2014-10-06 00:00:00+00:00   1.2514
# 2014-10-07 00:00:00+00:00   1.2646
#                              ...
# 2021-05-24 00:00:00+00:00   1.2183
# 2021-05-25 00:00:00+00:00   1.2215
# 2021-05-26 00:00:00+00:00   1.2249
# 2021-05-27 00:00:00+00:00   1.2193
# 2021-05-28 00:00:00+00:00   1.2193
# Name: (Close, EURUSD=X), Length: 1738, dtype: float64

# %%
df.xs('BTC=USD', axis=1, level=1)
# Out:
# Price                      Adj Close  Close  High  Low  Open  Volume
# Date
# 2014-10-01 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
# 2014-10-02 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
# 2014-10-03 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
# 2014-10-06 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
# 2014-10-07 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
# ...                              ...    ...   ...  ...   ...     ...
# 2021-05-24 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
# 2021-05-25 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
# 2021-05-26 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
# 2021-05-27 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
# 2021-05-28 00:00:00+00:00        NaN    NaN   NaN  NaN   NaN     NaN
#
# [1738 rows x 6 columns]

# %%
df['Close'].describe()
# Out:
# Ticker        BA  BTC=USD        DJI  EURUSD=X      GC=F      MSFT
# count  1677.0000   0.0000  1517.0000 1735.0000 1674.0000 1677.0000
# mean    228.7380      NaN 22572.5205    1.1406 1372.0145  106.3144
# std      94.3742      NaN  4684.0823    0.0501  235.7154   60.7722
# min      95.0100      NaN 15660.2002    1.0390 1050.8000   40.2900
# 25%     143.3400      NaN 18003.8008    1.1054 1216.5500   54.8300
# 50%     189.0800      NaN 22158.1992    1.1300 1283.1500   89.7100
# 75%     335.1600      NaN 25735.0000    1.1777 1482.3000  138.9000
# max     440.6200      NaN 34777.8008    1.2822 2051.5000  261.9700

# %%
close.BA.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 close.BA.dropna().plot(figsize = (15, 8), fontsize = 13)
#       2 plt.legend(fontsize = 13)
#       3 plt.show()
#
# NameError: name 'close' is not defined

# %%
df[('Close', 'BA')].dropna().plot(figsize=(15, 8))
plt.legend(fontsize=13)
plt.show()

# %%
df[('Close')].dropna().plot(figsize=(15, 8))
plt.legend(fontsize=13)
plt.show()

# %% [markdown]
# Normalizing Finiancial Time Series to a Base Value
# all instruments start at the same level.

# %%
close
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 close
#
# NameError: name 'close' is not defined

# %%
close = df[('Close')]
close
# Out:
# Ticker                          BA  BTC=USD        DJI  EURUSD=X      GC=F  \
# Date
# 2014-10-01 00:00:00+00:00 124.6700      NaN 16804.6992    1.2628 1214.6000
# 2014-10-02 00:00:00+00:00 124.1700      NaN 16801.0996    1.2624 1214.2000
# 2014-10-03 00:00:00+00:00 126.3600      NaN 17009.6992    1.2671 1192.2000
# 2014-10-06 00:00:00+00:00 126.2600      NaN 16991.9004    1.2514 1206.7000
# 2014-10-07 00:00:00+00:00 123.3200      NaN 16719.4004    1.2646 1211.7000
# ...                            ...      ...        ...       ...       ...
# 2021-05-24 00:00:00+00:00 237.4400      NaN 34394.0000    1.2183 1884.6000
# 2021-05-25 00:00:00+00:00 240.7400      NaN 34312.5000    1.2215 1898.1000
# 2021-05-26 00:00:00+00:00 241.3700      NaN 34323.1016    1.2249 1901.3000
# 2021-05-27 00:00:00+00:00 250.7000      NaN 34464.6016    1.2193 1895.7000
# 2021-05-28 00:00:00+00:00 247.0200      NaN 34529.3984    1.2193 1902.5000
#
# Ticker                        MSFT
# Date
# ...

# %%
close.iloc[0, 0]
# Out:
# 124.66999816894533

# %%
close.BA.div(close.iloc[0,0])
# Out:
# Date
# 2014-10-01 00:00:00+00:00   1.0000
# 2014-10-02 00:00:00+00:00   0.9960
# 2014-10-03 00:00:00+00:00   1.0136
# 2014-10-06 00:00:00+00:00   1.0128
# 2014-10-07 00:00:00+00:00   0.9892
#                              ...
# 2021-05-24 00:00:00+00:00   1.9045
# 2021-05-25 00:00:00+00:00   1.9310
# 2021-05-26 00:00:00+00:00   1.9361
# 2021-05-27 00:00:00+00:00   2.0109
# 2021-05-28 00:00:00+00:00   1.9814
# Name: BA, Length: 1738, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(500)
norm
# Out:
# Ticker                           BA  BTC=USD       DJI  EURUSD=X     GC=F  \
# Date
# 2014-10-01 00:00:00+00:00  500.0000      NaN  500.0000  500.0000 500.0000
# 2014-10-02 00:00:00+00:00  497.9947      NaN  499.8929  499.8359 499.8353
# 2014-10-03 00:00:00+00:00  506.7779      NaN  506.0995  501.6725 490.7788
# 2014-10-06 00:00:00+00:00  506.3769      NaN  505.5699  495.4575 496.7479
# 2014-10-07 00:00:00+00:00  494.5857      NaN  497.4621  500.7019 498.8062
# ...                             ...      ...       ...       ...      ...
# 2021-05-24 00:00:00+00:00  952.2740      NaN 1023.3447  482.3769 775.8110
# 2021-05-25 00:00:00+00:00  965.5090      NaN 1020.9198  483.6202 781.3684
# 2021-05-26 00:00:00+00:00  968.0356      NaN 1021.2352  484.9844 782.6857
# 2021-05-27 00:00:00+00:00 1005.4544      NaN 1025.4454  482.7475 780.3804
# 2021-05-28 00:00:00+00:00  990.6955      NaN 1027.3733  482.7710 783.1797
#
# Ticker                         MSFT
# Date
# ...

# %%
norm.dropna().plot(figsize = (15, 8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()

# %%
close.to_csv("close.csv")
