# %% [markdown]
# Defining an SMA Crossover Strategy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use("seabor")

# %%
data = pd.read_csv("eurusd.csv", parse_dates = ["Date"], index_col = "Date")

# %%
data
# Out:
#                price
# Date
# 2004-01-01  1.258194
# 2004-01-02  1.258194
# 2004-01-05  1.268698
# 2004-01-06  1.272103
# 2004-01-07  1.264095
# ...              ...
# 2020-06-24  1.131235
# 2020-06-25  1.125087
# 2020-06-26  1.122208
# 2020-06-29  1.122586
# 2020-06-30  1.124720
#
# [4275 rows x 1 columns]

# %%
sma_s = 50
sma_l = 200

# %%
data.price.rolling(50).mean()
# Out:
# Date
# 2004-01-01         NaN
# 2004-01-02         NaN
# 2004-01-05         NaN
# 2004-01-06         NaN
# 2004-01-07         NaN
#                 ...
# 2020-06-24    1.101794
# 2020-06-25    1.102486
# 2020-06-26    1.103213
# 2020-06-29    1.103931
# 2020-06-30    1.104695
# Name: price, Length: 4275, dtype: float64

# %%
data["SMA_S"] = data.price.rolling(sma_s).mean()

# %%
data["SMA_L"] = data.price.rolling(sma_l).mean()

# %%
data
# Out:
#                price     SMA_L     SMA_S
# Date
# 2004-10-06  1.228094       NaN       NaN
# 2004-10-07  1.229906       NaN       NaN
# 2004-10-08  1.241003       NaN       NaN
# 2004-10-11  1.238405       NaN       NaN
# 2004-10-12  1.232104       NaN       NaN
# ...              ...       ...       ...
# 2020-06-24  1.131235  1.103430  1.101794
# 2020-06-25  1.125087  1.103540  1.102486
# 2020-06-26  1.122208  1.103627  1.103213
# 2020-06-29  1.122586  1.103730  1.103931
# 2020-06-30  1.124720  1.103857  1.104695
#
# [4076 rows x 3 columns]

# %%
print(data.columns)
# Out:
# Index(['price', 'SMA_L', 'SMA_S'], dtype='object')

# %%
data.plot(figsize = (12, 8), title = "EUR/USD - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12)
# Out:
# <Axes: title={'center': 'EUR/USD - SMA50 | SMA200'}, xlabel='Date'>

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                price     SMA_L     SMA_S
# Date
# 2005-07-13  1.208007  1.286260  1.231663
# 2005-07-14  1.209395  1.286167  1.229938
# 2005-07-15  1.204602  1.286040  1.228406
# 2005-07-18  1.205604  1.285863  1.226809
# 2005-07-19  1.202993  1.285686  1.225095
# ...              ...       ...       ...
# 2020-06-24  1.131235  1.103430  1.101794
# 2020-06-25  1.125087  1.103540  1.102486
# 2020-06-26  1.122208  1.103627  1.103213
# 2020-06-29  1.122586  1.103730  1.103931
# 2020-06-30  1.124720  1.103857  1.104695
#
# [3877 rows x 3 columns]

# %%
data.loc["2016"].plot(figsize = (12, 8), title = "EUR/USD - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12)
# Out:
# <Axes: title={'center': 'EUR/USD - SMA50 | SMA200'}, xlabel='Date'>

# %%
data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)

# %%
data
# Out:
#                price     SMA_L     SMA_S  position
# Date
# 2005-07-13  1.208007  1.286260  1.231663        -1
# 2005-07-14  1.209395  1.286167  1.229938        -1
# 2005-07-15  1.204602  1.286040  1.228406        -1
# 2005-07-18  1.205604  1.285863  1.226809        -1
# 2005-07-19  1.202993  1.285686  1.225095        -1
# ...              ...       ...       ...       ...
# 2020-06-24  1.131235  1.103430  1.101794        -1
# 2020-06-25  1.125087  1.103540  1.102486        -1
# 2020-06-26  1.122208  1.103627  1.103213        -1
# 2020-06-29  1.122586  1.103730  1.103931         1
# 2020-06-30  1.124720  1.103857  1.104695         1
#
# [3877 rows x 4 columns]

# %%
data.loc[:, ["SMA_S", "SMA_L", "position"]].plot(
    figsize=(12, 8), 
    fontsize=12, 
    secondary_y=["position"],  # secondary_y expects a list of column names
    title="EUR/USD - SMA{} | SMA{}".format(sma_s, sma_l)
)
# Out:
# <Axes: title={'center': 'EUR/USD - SMA50 | SMA200'}, xlabel='Date'>

# %%
data.loc["2016", ["SMA_S", "SMA_L", "position"]].plot(
    figsize=(12, 8), 
    fontsize=12, 
    secondary_y=["position"],  # secondary_y expects a list of column names
    title="EUR/USD - SMA{} | SMA{}".format(sma_s, sma_l)
)
# Out:
# <Axes: title={'center': 'EUR/USD - SMA50 | SMA200'}, xlabel='Date'>
