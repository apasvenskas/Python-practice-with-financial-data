# %% [markdown]
# Generalization with OOP: The SMA Backtester

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product

# %%
df = pd.read_csv("forex_pairs.csv", parse_dates = ["Date"], index_col = "Date")
df
# Out:
#             AUDEUR=X  EURUSD=X  USDGBP=X
# Date
# 2004-01-01   0.59780  1.258194   0.56016
# 2004-01-02   0.60314  1.258194   0.55751
# 2004-01-05   0.60467  1.268698   0.55334
# 2004-01-06   0.60350  1.272103   0.54906
# 2004-01-07   0.60728  1.264095   0.55012
# ...              ...       ...       ...
# 2020-06-24   0.61349  1.131235   0.79841
# 2020-06-25   0.60938  1.125087   0.80561
# 2020-06-26   0.61373  1.122208   0.80480
# 2020-06-29   0.61128  1.122586   0.81023
# 2020-06-30   0.61097  1.124720   0.81231
#
# [4295 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4295 entries, 2004-01-01 to 2020-06-30
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AUDEUR=X  4274 non-null   float64
#  1   EURUSD=X  4275 non-null   float64
#  2   USDGBP=X  4287 non-null   float64
# dtypes: float64(3)
# memory usage: 134.2 KB

# %%
import SMABacktester as SMA

# %%
tester = SMA.SMABacktester("EURUSD=X", 50, 200, "2004-01-01", "2020-06-30")
tester.test_strategy()
# Out:
# (1.2835, 0.367674)

# %%
tester.results
# Out:
#                price   returns     SMA_S     SMA_L  position  strategy  \
# Date
# 2004-10-07  1.229906  0.001475  1.221840  1.226081        -1 -0.001475
# 2004-10-08  1.241003  0.008982  1.222628  1.225995        -1 -0.008982
# 2004-10-11  1.238405 -0.002095  1.223352  1.225843        -1  0.002095
# 2004-10-12  1.232104 -0.005102  1.223888  1.225643        -1  0.005102
# 2004-10-13  1.234903  0.002270  1.224466  1.225497        -1 -0.002270
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.002892  1.101794  1.103430        -1 -0.002892
# 2020-06-25  1.125087 -0.005449  1.102486  1.103540        -1  0.005449
# 2020-06-26  1.122208 -0.002562  1.103213  1.103627        -1  0.002562
# 2020-06-29  1.122586  0.000337  1.103931  1.103730         1 -0.000337
# 2020-06-30  1.124720  0.001899  1.104695  1.103857         1  0.001899
#
#             creturns  cstrategy
# Date
# 2004-10-07  1.001476   0.998526
# 2004-10-08  1.010511   0.989598
# ...

# %%
tester.plot_results()

# %%
tester.set_parameters(75, 150)

# %%
tester.test_strategy()
# Out:
# (1.58974, 0.655896)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((25, 50, 11), (100, 200, 1))
# Out:
# ((47, 136), 2.513588)

# %%
tester.plot_results()

# %%
tester.results_overview
# Out:
#      SMA_S  SMA_L  performance
# 0       25    100     1.236187
# 1       25    101     1.261659
# 2       25    102     1.217403
# 3       25    103     1.305591
# 4       25    104     1.345555
# ..     ...    ...          ...
# 295     47    195     1.294778
# 296     47    196     1.272171
# 297     47    197     1.250562
# 298     47    198     1.315134
# 299     47    199     1.338583
#
# [300 rows x 3 columns]

# %% [markdown]
# Backtesting & Forward testing

# %%
train = SMA.SMABacktester("EURUSD=X", 50, 200, "2004-01-01", "2015-12-31")

# %%
train.optimize_parameters((25, 50, 1), (100, 200, 1))
# Out:
# ((46, 137), 2.440535)

# %%
train.plot_results()

# %%
tester = SMA.SMABacktester("EURUSD=X", 46, 137, "2016-01-01", "2020-06-30")

# %%
tester.test_strategy()
# Out:
# (1.056731, 0.038331)

# %%
tester.plot_results()

# %% [markdown]
# Builidng the SMABacktester Class from scratch: Instatiation

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None

# %%
tester = SMA.SMABacktester("AUDEUR=X", 50, 200, "2004-06-30", "2020-12-31")

# %%
tester.symbol
# Out:
# 'AUDEUR=X'

# %%
tester.results

# %% [markdown]
# Method get_data()

# %%
raw = pd.read_csv("forex_pairs.csv", parse_dates = ["Date"], index_col = "Date")
raw
# Out:
#             AUDEUR=X  EURUSD=X  USDGBP=X
# Date
# 2004-01-01   0.59780  1.258194   0.56016
# 2004-01-02   0.60314  1.258194   0.55751
# 2004-01-05   0.60467  1.268698   0.55334
# 2004-01-06   0.60350  1.272103   0.54906
# 2004-01-07   0.60728  1.264095   0.55012
# ...              ...       ...       ...
# 2020-06-24   0.61349  1.131235   0.79841
# 2020-06-25   0.60938  1.125087   0.80561
# 2020-06-26   0.61373  1.122208   0.80480
# 2020-06-29   0.61128  1.122586   0.81023
# 2020-06-30   0.61097  1.124720   0.81231
#
# [4295 rows x 3 columns]

# %%
raw = raw["AUDEUR=X"].to_frame().dropna()
raw
# Out:
#             AUDEUR=X
# Date
# 2004-01-01   0.59780
# 2004-01-02   0.60314
# 2004-01-05   0.60467
# 2004-01-06   0.60350
# 2004-01-07   0.60728
# ...              ...
# 2020-06-24   0.61349
# 2020-06-25   0.60938
# 2020-06-26   0.61373
# 2020-06-29   0.61128
# 2020-06-30   0.61097
#
# [4274 rows x 1 columns]

# %%
raw = raw.loc["2010-01-01":"2012-12-31"].copy()
raw
# Out:
#             AUDEUR=X
# Date
# 2010-01-01   0.62402
# 2010-01-04   0.63230
# 2010-01-05   0.63430
# 2010-01-06   0.63860
# 2010-01-07   0.64060
# ...              ...
# 2012-12-25   0.78620
# 2012-12-26   0.78680
# 2012-12-27   0.78340
# 2012-12-28   0.78250
# 2012-12-31   0.78540
#
# [781 rows x 1 columns]

# %%
raw.rename(columns={"AUDEUR=X": "price"}, inplace=True) #Clean up
raw
# Out:
#               price
# Date
# 2010-01-01  0.62402
# 2010-01-04  0.63230
# 2010-01-05  0.63430
# 2010-01-06  0.63860
# 2010-01-07  0.64060
# ...             ...
# 2012-12-25  0.78620
# 2012-12-26  0.78680
# 2012-12-27  0.78340
# 2012-12-28  0.78250
# 2012-12-31  0.78540
#
# [781 rows x 1 columns]

# %%
raw["returns"] = np.log(raw["price"] / raw["price"].shift(1)).fillna(0)

# %%
raw["SMA_S"] = raw["price"].rolling(50).mean() # add short and long sma strategy
raw["SMA_L"] = raw["price"].rolling(200).mean()

# %%
raw
# Out:
#               price   returns     SMA_S     SMA_L
# Date
# 2010-01-01  0.62402  0.000000       NaN       NaN
# 2010-01-04  0.63230  0.013182       NaN       NaN
# 2010-01-05  0.63430  0.003158       NaN       NaN
# 2010-01-06  0.63860  0.006756       NaN       NaN
# 2010-01-07  0.64060  0.003127       NaN       NaN
# ...             ...       ...       ...       ...
# 2012-12-25  0.78620 -0.002921  0.803610  0.805435
# 2012-12-26  0.78680  0.000763  0.803618  0.805410
# 2012-12-27  0.78340 -0.004331  0.803462  0.805372
# 2012-12-28  0.78250 -0.001149  0.803238  0.805347
# 2012-12-31  0.78540  0.003699  0.803118  0.805327
#
# [781 rows x 4 columns]

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()

    def get_data(self):
        raw = pd.read_csv("forex_pairs.csv", parse_dates = ["Date"], index_col = "Date")
        raw = raw[self.symbol].to_frame().dropna()
        raw = raw.loc[self.start:self.end].copy()
        raw.rename(columns={self.symbol: "price"}, inplace=True)
        raw["returns"] = np.log(raw["price"] / raw["price"].shift(1)).fillna(0)
        raw["SMA_S"] = raw["price"].rolling(self.SMA_S).mean() # add short and long sma strategy
        raw["SMA_L"] = raw["price"].rolling(self.SMA_L).mean()
        self.data = raw
        return raw

# %%
tester = SMABacktester("AUDEUR=X", 50, 200, "2010-01-01", "2019-12-31")

# %%
tester.data
# Out:
#               price   returns     SMA_S     SMA_L
# Date
# 2010-01-01  0.62402  0.000000       NaN       NaN
# 2010-01-04  0.63230  0.013182       NaN       NaN
# 2010-01-05  0.63430  0.003158       NaN       NaN
# 2010-01-06  0.63860  0.006756       NaN       NaN
# 2010-01-07  0.64060  0.003127       NaN       NaN
# ...             ...       ...       ...       ...
# 2019-12-25  0.62410 -0.000240  0.617223  0.619946
# 2019-12-26  0.62380 -0.000481  0.617499  0.619907
# 2019-12-27  0.62550  0.002722  0.617745  0.619901
# 2019-12-30  0.62441 -0.001744  0.617958  0.619868
# 2019-12-31  0.62493  0.000833  0.618139  0.619838
#
# [2586 rows x 4 columns]

# %% [markdown]
# Setting new SMA parameter

# %%
tester.SMA_S
# Out:
# 50

# %%
tester.SMA_L
# Out:
# 200

# %%
tester.data
# Out:
#               price   returns     SMA_S     SMA_L
# Date
# 2010-01-01  0.62402  0.000000       NaN       NaN
# 2010-01-04  0.63230  0.013182       NaN       NaN
# 2010-01-05  0.63430  0.003158       NaN       NaN
# 2010-01-06  0.63860  0.006756       NaN       NaN
# 2010-01-07  0.64060  0.003127       NaN       NaN
# ...             ...       ...       ...       ...
# 2019-12-25  0.62410 -0.000240  0.617223  0.619946
# 2019-12-26  0.62380 -0.000481  0.617499  0.619907
# 2019-12-27  0.62550  0.002722  0.617745  0.619901
# 2019-12-30  0.62441 -0.001744  0.617958  0.619868
# 2019-12-31  0.62493  0.000833  0.618139  0.619838
#
# [2586 rows x 4 columns]

# %%
tester.SMA_L = 250

# %%
tester.SMA_L
# Out:
# 250

# %%
tester.data.isna().sum()
# Out:
# price        0
# returns      0
# SMA_S       49
# SMA_L      199
# dtype: int64

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()

    def get_data(self):
        raw = pd.read_csv("forex_pairs.csv", parse_dates = ["Date"], index_col = "Date")
        raw = raw[self.symbol].to_frame().dropna()
        raw = raw.loc[self.start:self.end].copy()
        raw.rename(columns={self.symbol: "price"}, inplace=True)
        raw["returns"] = np.log(raw["price"] / raw["price"].shift(1)).fillna(0)
        raw["SMA_S"] = raw["price"].rolling(self.SMA_S).mean() # add short and long sma strategy
        raw["SMA_L"] = raw["price"].rolling(self.SMA_L).mean()
        self.data = raw
        return raw

    def set_parameters(self, SMA_S = None, SMA_L = None): # updating SMA_S and SMA_L values.
        if SMA_S is not None:
            self.SMA_S = SMA_S
            self.data["SMA_S"] = self.data["price"].rolling(self.SMA_S).mean()
        if SMA_L is not None:
            self.SMA_L = SMA_L
            self.data["SMA_L"] = self.data["price"].rolling(self.SMA_L).mean()

# %%
tester = SMABacktester("AUDEUR=X", 50, 200, "2010-01-01", "2019-12-31")

# %%
tester.data.isna().sum()
# Out:
# price        0
# returns      0
# SMA_S       49
# SMA_L      199
# dtype: int64

# %%
tester.set_parameters(SMA_S = 25, SMA_L = 150)

# %%
tester.SMA_S
# Out:
# 25

# %%
tester.data.isna().sum()
# Out:
# price        0
# returns      0
# SMA_S       24
# SMA_L      149
# dtype: int64

# %% [markdown]
# Trading Strategy

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()

    def get_data(self):
        raw = pd.read_csv("forex_pairs.csv", parse_dates = ["Date"], index_col = "Date")
        raw = raw[self.symbol].to_frame().dropna()
        raw = raw.loc[self.start:self.end].copy()
        raw.rename(columns={self.symbol: "price"}, inplace=True)
        raw["returns"] = np.log(raw["price"] / raw["price"].shift(1)).fillna(0)
        raw["SMA_S"] = raw["price"].rolling(self.SMA_S).mean() # add short and long sma strategy
        raw["SMA_L"] = raw["price"].rolling(self.SMA_L).mean()
        self.data = raw
        return raw

    def set_parameters(self, SMA_S = None, SMA_L = None): # updating SMA_S and SMA_L values.
        if SMA_S is not None:
            self.SMA_S = SMA_S
            self.data["SMA_S"] = self.data["price"].rolling(self.SMA_S).mean()
        if SMA_L is not None:
            self.SMA_L = SMA_L
            self.data["SMA_L"] = self.data["price"].rolling(self.SMA_L).mean()

    def test_strategy(self):
        data = self.data.copy().dropna()
        data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)
        data["strategy"] = data["position"].shift(1) * data["returns"]
        data.dropna(inplace=True)
        data["creturns"] = data["returns"].cumsum().apply(np.exp)
        data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
        self.results = data

        perf = data["cstrategy"].iloc[-1]
        outperf = perf - data["creturns"].iloc[-1]
        return round(perf, 6), round(outperf, 6)

# %%
tester = SMABacktester("EURUSD=X", 50, 200, "2004-01-01", "2020-06-30")

# %%
tester.test_strategy()
# Out:
# (1.2835, 0.367674)

# %%
tester.results
# Out:
#                price   returns     SMA_S     SMA_L  position  strategy  \
# Date
# 2004-10-07  1.229906  0.001475  1.221840  1.226081        -1 -0.001475
# 2004-10-08  1.241003  0.008982  1.222628  1.225995        -1 -0.008982
# 2004-10-11  1.238405 -0.002095  1.223352  1.225843        -1  0.002095
# 2004-10-12  1.232104 -0.005102  1.223888  1.225643        -1  0.005102
# 2004-10-13  1.234903  0.002270  1.224466  1.225497        -1 -0.002270
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.002892  1.101794  1.103430        -1 -0.002892
# 2020-06-25  1.125087 -0.005449  1.102486  1.103540        -1  0.005449
# 2020-06-26  1.122208 -0.002562  1.103213  1.103627        -1  0.002562
# 2020-06-29  1.122586  0.000337  1.103931  1.103730         1 -0.000337
# 2020-06-30  1.124720  0.001899  1.104695  1.103857         1  0.001899
#
#             creturns  cstrategy
# Date
# 2004-10-07  1.001476   0.998526
# 2004-10-08  1.010511   0.989598
# ...

# %% [markdown]
# Plotting the results

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()

    def get_data(self):
        raw = pd.read_csv("forex_pairs.csv", parse_dates = ["Date"], index_col = "Date")
        raw = raw[self.symbol].to_frame().dropna()
        raw = raw.loc[self.start:self.end].copy()
        raw.rename(columns={self.symbol: "price"}, inplace=True)
        raw["returns"] = np.log(raw["price"] / raw["price"].shift(1)).fillna(0)
        raw["SMA_S"] = raw["price"].rolling(self.SMA_S).mean() # add short and long sma strategy
        raw["SMA_L"] = raw["price"].rolling(self.SMA_L).mean()
        self.data = raw
        return raw

    def set_parameters(self, SMA_S = None, SMA_L = None): # updating SMA_S and SMA_L values.
        if SMA_S is not None:
            self.SMA_S = SMA_S
            self.data["SMA_S"] = self.data["price"].rolling(self.SMA_S).mean()
        if SMA_L is not None:
            self.SMA_L = SMA_L
            self.data["SMA_L"] = self.data["price"].rolling(self.SMA_L).mean()

    def test_strategy(self):
        data = self.data.copy().dropna()
        data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)
        data["strategy"] = data["position"].shift(1) * data["returns"]
        data.dropna(inplace=True)
        data["creturns"] = data["returns"].cumsum().apply(np.exp)
        data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
        self.results = data

        perf = data["cstrategy"].iloc[-1]
        outperf = perf - data["creturns"].iloc[-1]
        return round(perf, 6), round(outperf, 6)

    def plot_results(self):
        if self.results is None:
            print("Run test_strategy() first.")
        else:
            title = "{} | SMA_S = {} | SMA_L = {}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["creturns", "cstrategy"]].plot(title=title, figsize=(12, 8))

# %%
tester = SMABacktester("EURUSD=X", 50, 200, "2004-01-01", "2020-06-30")

# %%
tester.plot_results()
# Out:
# Run test_strategy() first.

# %%
tester.test_strategy()
# Out:
# (1.2835, 0.367674)

# %%
tester.plot_results()

# %% [markdown]
# Strategy Optimization

# %%
tester.set_parameters(25, 150)

# %%
tester.test_strategy()
# Out:
# (1.586563, 0.652719)

# %% [markdown]
# Strategy Optimization

# %%
tester.set_parameters(25, 150)

# %%
tester.test_strategy()
# Out:
# (1.586563, 0.652719)

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()

    def get_data(self):
        raw = pd.read_csv("forex_pairs.csv", parse_dates = ["Date"], index_col = "Date")
        raw = raw[self.symbol].to_frame().dropna()
        raw = raw.loc[self.start:self.end].copy()
        raw.rename(columns={self.symbol: "price"}, inplace=True)
        raw["returns"] = np.log(raw["price"] / raw["price"].shift(1)).fillna(0)
        raw["SMA_S"] = raw["price"].rolling(self.SMA_S).mean() # add short and long sma strategy
        raw["SMA_L"] = raw["price"].rolling(self.SMA_L).mean()
        self.data = raw
        return raw

    def set_parameters(self, SMA_S = None, SMA_L = None): # updating SMA_S and SMA_L values.
        if SMA_S is not None:
            self.SMA_S = SMA_S
            self.data["SMA_S"] = self.data["price"].rolling(self.SMA_S).mean()
        if SMA_L is not None:
            self.SMA_L = SMA_L
            self.data["SMA_L"] = self.data["price"].rolling(self.SMA_L).mean()

    def test_strategy(self):
        data = self.data.copy().dropna()
        data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)
        data["strategy"] = data["position"].shift(1) * data["returns"]
        data.dropna(inplace=True)
        data["creturns"] = data["returns"].cumsum().apply(np.exp)
        data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
        self.results = data

        perf = data["cstrategy"].iloc[-1]
        outperf = perf - data["creturns"].iloc[-1]
        return round(perf, 6), round(outperf, 6)

    def plot_results(self):
        if self.results is None:
            print("Run test_strategy() first.")
        else:
            title = "{} | SMA_S = {} | SMA_L = {}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["creturns", "cstrategy"]].plot(title=title, figsize=(12, 8))

    def optimize_parameters(self, SMA_S_range, SMA_L_range):
        combinations = list(product(range(*SMA_S_range), range(*SMA_L_range)))

        # tests all combinations
        results = []
        for comb in combinations:
            self.set_parameters(comb[0], comb[1])
            results.append(self.test_strategy()[0])

        best_perf = np.max(results)
        opt = combinations[np.argmax(results)]

        # run/set the optimat strg
        self.set_parameters(opt[0], opt[1])
        self.test_strategy()

        many_results = pd.DataFrame(data = combinations, columns = ["SMA_S", "SMA_L"])
        many_results["performance"] = results
        self.results_overview = many_results

        return opt, best_perf

# %%
tester = SMABacktester("EURUSD=X", 50, 200, "2004-01-01", "2020-06-30")

# %%
tester.test_strategy()
# Out:
# (1.2835, 0.367674)

# %%
tester.optimize_parameters((10, 50, 1), (100, 252, 1))
# Out:
# ((46, 137), 2.526694)

# %%
tester.plot_results()

# %% [markdown]
# String Representation & Docstrings

# %%
tester

# %%
tester.optimize_parameters()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 tester.optimize_parameters()
#
# TypeError: SMABacktester.optimize_parameters() missing 2 required positional arguments: 'SMA_S_range' and 'SMA_L_range'

# %%
class SMABacktester():
    '''Class for vectorized backtesting of SMA-based trading strategies.
    '''
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        '''
        parameters 
        ----------
        symbol str:
            ticker symbol instrument to be backtested
        SMA_S: int
            moving window in bars for short SMA
        SMA_L: int
            moving window in bars for long SMA
        start: str
            start date for data import
        end: str
            end date of the import
        '''
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()

    def get_data(self):
        '''
        Prepares data for strategy (backstating).
        '''
        raw = pd.read_csv("forex_pairs.csv", parse_dates = ["Date"], index_col = "Date")
        raw = raw[self.symbol].to_frame().dropna()
        raw = raw.loc[self.start:self.end].copy()
        raw.rename(columns={self.symbol: "price"}, inplace=True)
        raw["returns"] = np.log(raw["price"] / raw["price"].shift(1)).fillna(0)
        raw["SMA_S"] = raw["price"].rolling(self.SMA_S).mean() # add short and long sma strategy
        raw["SMA_L"] = raw["price"].rolling(self.SMA_L).mean()
        self.data = raw
        return raw

    def prepare_data(self):
        '''
        Prepares data for strategy backstaking.
        '''
        data = self.data.copy()
        data["SMA_S"] = data["price"].rolling(self.SMA_S).mean()
        data["SMA_L"] = data["price"].rolling(self.SMA_L).mean()
        self.data = data

    def set_parameters(self, SMA_S = None, SMA_L = None): # updating SMA_S and SMA_L values.
        '''
        update SMA parameters and the prepared dataset.
        '''
        if SMA_S is not None:
            self.SMA_S = SMA_S
            self.data["SMA_S"] = self.data["price"].rolling(self.SMA_S).mean()
        if SMA_L is not None:
            self.SMA_L = SMA_L
            self.data["SMA_L"] = self.data["price"].rolling(self.SMA_L).mean()

    def test_strategy(self):
        '''
        Backtest the strategy
        '''
        data = self.data.copy().dropna()
        data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)
        data["strategy"] = data["position"].shift(1) * data["returns"]
        data.dropna(inplace=True)
        data["creturns"] = data["returns"].cumsum().apply(np.exp)
        data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
        self.results = data

        perf = data["cstrategy"].iloc[-1]
        outperf = perf - data["creturns"].iloc[-1]
        return round(perf, 6), round(outperf, 6)

    def plot_results(self):
        if self.results is None:
            print("Run test_strategy() first.")
        else:
            title = "{} | SMA_S = {} | SMA_L = {}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["creturns", "cstrategy"]].plot(title=title, figsize=(12, 8))

    def optimize_parameters(self, SMA_S_range, SMA_L_range):
        combinations = list(product(range(*SMA_S_range), range(*SMA_L_range)))

        # tests all combinations
        results = []
        for comb in combinations:
            self.set_parameters(comb[0], comb[1])
            results.append(self.test_strategy()[0])

        best_perf = np.max(results)
        opt = combinations[np.argmax(results)]

        # run/set the optimat strg
        self.set_parameters(opt[0], opt[1])
        self.test_strategy()

        many_results = pd.DataFrame(data = combinations, columns = ["SMA_S", "SMA_L"])
        many_results["performance"] = results
        self.results_overview = many_results

        return opt, best_perf
